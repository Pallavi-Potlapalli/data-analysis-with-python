# %%
#importing required libraries
import requests
#accessing the url
url = "https://trains.p.rapidapi.com/"
payload = { "search": "Rajdhani" }
headers = {
	"content-type": "application/json",
	"X-RapidAPI-Key": "03b90b4b54mshb88ccc0232d0d0ap126379jsna5f14345e1e1",
	"X-RapidAPI-Host": "trains.p.rapidapi.com"
}

response = requests.post(url, json=payload, headers=headers)
print(response.json())
# Out:
# [{'train_num': 12235, 'name': 'Dibrugarh - New Delhi Rajdhani Express', 'train_from': 'DBRG', 'train_to': 'NDLS', 'data': {'id': '7974', 'days': {'Fri': '0', 'Mon': '0', 'Sat': '0', 'Sun': '0', 'Thu': 1, 'Tue': '0', 'Wed': '0'}, 'to_id': '664', 'classes': ['3A', '2A', '1A'], 'from_id': '7288', 'arriveTime': '13:55 +2 nights', 'departTime': '19:25'}}, {'train_num': 12236, 'name': 'New Delhi - Dibrugarh Rajdhani Express', 'train_from': 'NDLS', 'train_to': 'DBRG', 'data': {'id': '7973', 'days': {'Fri': '0', 'Mon': '0', 'Sat': '0', 'Sun': '0', 'Thu': '0', 'Tue': 1, 'Wed': '0'}, 'to_id': '7288', 'classes': ['3A', '2A', '1A'], 'from_id': '664', 'arriveTime': '05:15 +2 nights', 'departTime': '09:25'}}, {'train_num': 12301, 'name': 'Howrah - New Delhi Rajdhani Express (via Gaya)', 'train_from': 'HWH', 'train_to': 'NDLS', 'data': {'id': '1316', 'days': {'Fri': 1, 'Mon': 1, 'Sat': 1, 'Sun': '0', 'Thu': 1, 'Tue': 1, 'Wed': 1}, 'to_id': '664', 'classes': ['3A', '2A', '1A'], 'from_id': '1', 'arri
# ...

# %%
#importing required libraries
import requests
#accessing the url
url = "https://trains.p.rapidapi.com/"

payload = { "search": "Rajdhani" }
headers = {
	"content-type": "application/json",
	"X-RapidAPI-Key": "03b90b4b54mshb88ccc0232d0d0ap126379jsna5f14345e1e1",
	"X-RapidAPI-Host": "trains.p.rapidapi.com"
}

response = requests.post(url, json=payload, headers=headers)

d=response.json()
print("train_num :",d[0]['train_num'])
print("train name :",d[0]['name'])
print("data :",d[0]['data']['days'])
print("classes :",d[0]['data']['classes'])
# Out:
# train_num : 12235
# train name : Dibrugarh - New Delhi Rajdhani Express
# data : {'Fri': '0', 'Mon': '0', 'Sat': '0', 'Sun': '0', 'Thu': 1, 'Tue': '0', 'Wed': '0'}
# classes : ['3A', '2A', '1A']

# %%
#importing required libraries
import requests
url = "https://trains.p.rapidapi.com/"
payload = { "search": "Rajdhani" }
headers = {
	"content-type": "application/json",
	"X-RapidAPI-Key": "03b90b4b54mshb88ccc0232d0d0ap126379jsna5f14345e1e1",
	"X-RapidAPI-Host": "trains.p.rapidapi.com"
}
response = requests.post(url, json=payload, headers=headers)
d=response.json()
for i in range(6):
  print("train i",i+1,"details:")
  print("train_num :",d[i]['train_num'])
  print("train name :",d[i]['name'])
  print("data :",d[i]['data']['days'])
  print("classes :",d[i]['data']['classes'])
# Out:
# train i 1 details:
# train_num : 12235
# train name : Dibrugarh - New Delhi Rajdhani Express
# data : {'Fri': '0', 'Mon': '0', 'Sat': '0', 'Sun': '0', 'Thu': 1, 'Tue': '0', 'Wed': '0'}
# classes : ['3A', '2A', '1A']
# train i 2 details:
# train_num : 12236
# train name : New Delhi - Dibrugarh Rajdhani Express
# data : {'Fri': '0', 'Mon': '0', 'Sat': '0', 'Sun': '0', 'Thu': '0', 'Tue': 1, 'Wed': '0'}
# classes : ['3A', '2A', '1A']
# train i 3 details:
# train_num : 12301
# train name : Howrah - New Delhi Rajdhani Express (via Gaya)
# data : {'Fri': 1, 'Mon': 1, 'Sat': 1, 'Sun': '0', 'Thu': 1, 'Tue': 1, 'Wed': 1}
# classes : ['3A', '2A', '1A']
# train i 4 details:
# train_num : 12302
# train name : New Delhi - Howrah Rajdhani Express (Via Gaya)
# data : {'Fri': '0', 'Mon': 1, 'Sat': 1, 'Sun': 1, 'Thu': 1, 'Tue': 1, 'Wed': 1}
# classes : ['3A', '2A', '1A']
# train i 5 details:
# train_num : 12305
# train name : Howrah - New Delhi Rajdhani  Express (via Patna)
# ...

# %%
#import required libraries
import requests
#accessing libraries
url = "https://trains.p.rapidapi.com/"
tr_name=input(("Enter train name:"))
payload = { "search": tr_name }
headers = {
	"content-type": "application/json",
	"X-RapidAPI-Key": "03b90b4b54mshb88ccc0232d0d0ap126379jsna5f14345e1e1",
	"X-RapidAPI-Host": "trains.p.rapidapi.com"
}
response = requests.post(url, json=payload, headers=headers)
d = response.json()
l=len(d)
for i in range(l):
  print("train",i+1, "details:")
  print("train_num :", d[i]['train_num'])
  print("train name :", d[i]['name'])
  print("data :",d[i]['data']['days'])
  print("classes :",d[i]['data']['classes'])
# Out:
# Enter train name:tirumala
# train 1 details:
# train_num : 17487
# train name : Tirumala Express
# data : {'Fri': 1, 'Mon': 1, 'Sat': 1, 'Sun': 1, 'Thu': 1, 'Tue': 1, 'Wed': 1}
# classes : ['II', 'SL', '3A', '2A']
# train 2 details:
# train_num : 17488
# train name : Tirumala Express
# data : {'Fri': 1, 'Mon': 1, 'Sat': 1, 'Sun': 1, 'Thu': 1, 'Tue': 1, 'Wed': 1}
# classes : ['II', 'SL', '3A', '2A']

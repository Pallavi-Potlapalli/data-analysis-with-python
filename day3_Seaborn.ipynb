# %%
import pandas as pd

# %%
mydf2=pd.read_csv("/content/mydf.csv")
mydf2
# Out:
#     Unnamed: 0   Names Initials      SEM1  SEM2       SEM3 Grade  Placed  \
# 0            0     Joe        K  9.800000  10.0   9.900000    A+       1
# 1            1  Rajesh        M  8.900000   9.1   9.300000     A       1
# 2            2  Kissan        V  9.900000   9.8  10.000000     A       0
# 3            3    Mary        N  7.700000   8.0   8.992857     B       0
# 4            4    Jeen        K  9.800000   9.1   9.900000    A+       1
# 5            5     Raj        M  8.900000   9.1   9.300000     A       1
# 6            6  Hassan        V  9.900000   9.0   9.200000     A       1
# 7            7    Mari        N  7.700000   8.0   7.100000     B       1
# 8            8    Jess        K  8.992857   9.1   9.900000    A+       1
# 9            9  Rajini        M  8.992857   9.1   9.300000     A       0
# 10          10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11          11    Maya        N  7.700000   8.0   7.100000     B       0
# ...

# %%
import seaborn as sns

# %%
p1 = sns.lineplot(x='Names',y='SEM1',data=mydf2)

# %%
sns.relplot(data=mydf2,x="SEM1",y="Names",col="Placed")
#COL==>GRAPHS ARE SEPERATED BASED ON THIS COLUMN

# %%
#create a relational plot using age as y-axis,index as x-axis,seperated by class
mydf3 = pd.read_excel("/content/diabetes.xlsx")
mydf3['Index'] = range(1,769)
mydf3
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class  Index
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive      1
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative      2
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive      3
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative      4
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive      5
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...    ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative    764
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative    765
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative    766
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive    767
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative    768
#
# [768 rows x 10 columns]

# %%
sns.relplot(data=mydf3,x="Index",y="age",col="class")

# %%
df = sns.load_dataset("tips")

# %%
sns.load_dataset("tips")
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=df, x="total_bill", y="tip", hue="sex")

# %%
sns.relplot(data=df, x="total_bill", y="tip", hue="smoker",style="time",palette="muted")

# %%
sns.relplot(data=df, x="total_bill", y="tip", hue="size")

# %%
dowjones = sns.load_dataset("dowjones")
dowjones
# Out:
#           Date   Price
# 0   1914-12-01   55.00
# 1   1915-01-01   56.55
# 2   1915-02-01   56.00
# 3   1915-03-01   58.30
# 4   1915-04-01   66.45
# ..         ...     ...
# 644 1968-08-01  883.72
# 645 1968-09-01  922.80
# 646 1968-10-01  955.47
# 647 1968-11-01  964.12
# 648 1968-12-01  965.39
#
# [649 rows x 2 columns]

# %%
dowjones.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
dowjones.tail()
# Out:
#           Date   Price
# 644 1968-08-01  883.72
# 645 1968-09-01  922.80
# 646 1968-10-01  955.47
# 647 1968-11-01  964.12
# 648 1968-12-01  965.39

# %%
sns.relplot(data=dowjones,x="Date",y="Price",kind="line")

# %%
fmri = sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
fmri.tail()
# Out:
#      subject  timepoint event    region    signal
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899

# %%
sns.relplot(data = fmri,x="timepoint",y="signal")

# %%
sns.catplot(data = df,x = "total_bill",y = 'smoker')

# %%
sns.catplot(data = df,y = "total_bill",x = 'time',kind="violin",hue="smoker")

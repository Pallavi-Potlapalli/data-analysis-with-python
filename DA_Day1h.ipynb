# %%
#creating a tuple
A_tuple = (0,[1,2,3],(4,5,6),7.0)
print(A_tuple)
# Out:
# (0, [1, 2, 3], (4, 5, 6), 7.0)

# %%
#accessing the elements from tuple
print("The first element: ", A_tuple[0])
print("The second element: ", A_tuple[-1])
print("The data type of the of the second element: ",type(A_tuple[1]))
# Out:
# The first element:  0
# The second element:  7.0
# The data type of the of the second element:  <class 'list'>

# %%
print(A_tuple[2][1])
# Out:
# 5

# %%
tuplea = 2,4,5,7,8,10
print(tuplea[:3])
print(tuplea[4:])
# Out:
# (2, 4, 5)
# (8, 10)

# %%
print(tuplea[-3:])
print(tuplea[2:5])
# Out:
# (7, 8, 10)
# (5, 7, 8)

# %%
tuple_1 = (1,2)
tuple_2 = (3,4)
print(tuple_1 + tuple_2)
# Out:
# (1, 2, 3, 4)

# %%
my_tuple = (1,2,3,4)
print(my_tuple *2)
# Out:
# (1, 2, 3, 4, 1, 2, 3, 4)

# %%
a = ('V', 'Jimin', 'Jungkook', 'Suga')
b = ('J-hope', 'Jin', 'Rm','Bts')
z = zip(a,b)
l=tuple(z)
print(l)
# Out:
# (('V', 'J-hope'), ('Jimin', 'Jin'), ('Jungkook', 'Rm'), ('Suga', 'Bts'))

# %%
thistuple = tuple(("apple","cherry","berry"))
print(thistuple)
# Out:
# ('apple', 'cherry', 'berry')

# %%
print(len(thistuple))
# Out:
# 3

# %%
thisset = {"jimin","suga","jungkook"}
print(thisset)
# Out:
# {'suga', 'jimin', 'jungkook'}

# %%
print(len(thisset))
# Out:
# 3

# %%
print(type(thisset))
# Out:
# <class 'set'>

# %%
thisset =set(("jimin","bts","rm"))
print(thisset)
# Out:
# {'rm', 'jimin', 'bts'}

# %%
set1 = {22,35,67}
set2 = {33,45,68}
union_set = set1 | set2
print(union_set)
# Out:
# {33, 35, 67, 68, 22, 45}

# %%
set1 = {22,35,67}
set2 = {33,45,68}
intersection_set = set1 & set2
print(intersection_set)
# Out:
# set()

# %%
set1 = {1,2,3,4,5}
set2 = {3,4,5,6,7}
set3 = set1.difference(set2)
print(set3)
set4 = set1 - set2
print(set4)
# Out:
# {1, 2}
# {1, 2}

# %%
set1 = {1,2,3,4,5}
set2 = {2,4}
print(set2.issubset(set1))
print(set1.issubset(set2))
# Out:
# True
# False

# %%
set1 = {1,2,3,4,5}
set1.discard(2)
print(set1)
# Out:
# {1, 3, 4, 5}
